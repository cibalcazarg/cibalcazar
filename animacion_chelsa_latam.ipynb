# %%
import cartopy
print(cartopy.__version__)
# Out:
# 0.25.0

# %%
pip install chelsa-cmip6
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import chelsa_cmip6

# %%
import chelsa_cmip6
dir(chelsa_cmip6)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']

# %%
from chelsa_cmip6 import get_data

ds = get_data(
    variable="tas",
    experiment="historical",
    model="MPI-ESM1-2-HR",
    start_year=1981,
    end_year=2010
)

ds
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from chelsa_cmip6 import get_data
#       3 ds = get_data(
#       4     variable="tas",
#       5     experiment="historical",
#    (...)
#       8     end_year=2010
#       9 )
#      11 ds
#
# ImportError: cannot import name 'get_data' from 'chelsa_cmip6' (C:\Users\Usuario\anaconda3\Lib\site-packages\chelsa_cmip6\__init__.py)

# %%
MPI-ESM1-2-HR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 MPI-ESM1-2-HR
#
# NameError: name 'MPI' is not defined

# %%
temp = ds['tas']

if float(temp.max()) > 100:
    temp = temp - 273.15

# %%
temp_year = temp.groupby("time.year").mean()
